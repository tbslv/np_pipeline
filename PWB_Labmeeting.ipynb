# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import seaborn as sns

# %%
path_preCNO = r"Y:\Data\PB_DATA\Neruopixel_ProcessedData\JPO-001991\Pre_CNO\2019-10-31_12-01-40\MUA-Analysis\JPO-001991_preCNO_probe1_001\-5\VPL_base.csv"
preCNO = pd.read_csv(path_preCNO,index_col=0)
chs_selection = (5,34)

preCNO_responsive = preCNO.loc[range(chs_selection[1]+1)]
sns.boxplot(x = 'exp',y = 'mean',data = preCNO_responsive)
sns.swarmplot(x="exp", y="mean", data=preCNO_responsive, color=".25")

plt.show()

# %%
path_postCNO = r"Y:\Data\PB_DATA\Neruopixel_ProcessedData\JPO-001991\Post_CNO\2019-11-01_12-13-08\MUA-Analysis\JPO-001991_postCNO_probe1_001\-5\VPL_base.csv"
postCNO = pd.read_csv(path_postCNO,index_col=0)
chs_selection = (5,34)

postCNO_responsive = postCNO.loc[range(chs_selection[1]+1)]
sns.boxplot(x = 'exp',y = 'mean',data = postCNO_responsive)
sns.swarmplot(x="exp", y="mean", data=postCNO_responsive, color=".25")

plt.show()
